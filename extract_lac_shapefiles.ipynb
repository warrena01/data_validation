# %%
import geopandas as gpd

# %%
shapefile = gpd.read_file('my_path')

# %%
shapefile
# Out:
#         CRESTA_ID                CRESTA_DES      GEOCODE_RE CRESTA_VER  \
# 0           ABW_1      Noord/Tanki Leendert  CRESTA HighRes       2019
# 1           ABW_2           Oranjestad West  CRESTA HighRes       2019
# 2           ABW_3           Oranjestad Oost  CRESTA HighRes       2019
# 3           ABW_4                  Paradera  CRESTA HighRes       2019
# 4           ABW_5                Santa Cruz  CRESTA HighRes       2019
# ...           ...                       ...             ...        ...
# 138384  POL_30326  Krakow (Krakow-Podgorze)  CRESTA HighRes       2019
# 138385  POL_30327  Krakow (Krakow-Podgorze)  CRESTA HighRes       2019
# 138386  POL_30328  Krakow (Krakow-Podgorze)  CRESTA HighRes       2019
# 138387  POL_30329  Krakow (Krakow-Podgorze)  CRESTA HighRes       2019
# 138388  POL_30331  Krakow (Krakow-Podgorze)  CRESTA HighRes       2019
#
#        GFK_VERSIO ISO3_ALPHA COUNTRY EDIT_NOTES CRESTA_LOW  Shape_STAr  \
# 0            2018        ABW   Aruba       None    ABW_ABW    0.002888
# 1            2018        ABW   Aruba       None    ABW_ABW    0.000768
# 2            2018        ABW   Aruba       None    ABW_ABW    0.001060
# 3            2018        ABW   Aruba       None    ABW_ABW    0.001704
# 4            2018        ABW   Aruba       None    ABW_ABW    0.003466
# ...           ...        ...     ...        ...        ...         ...
# 138384       2019        POL  Poland       None     POL_30    0.000002
# 138385       2019        POL  Poland       None     POL_30    0.000004
# 138386       2019        POL  Poland       None     POL_30    0.000018
# 138387       2019        POL  Poland       None     POL_30    0.000004
# 138388       2019        POL  Poland       None     POL_30    0.000018
#
#         Shape_STLe                                           geometry
# 0         0.317218  POLYGON ((-69.99333 12.56653, -69.99350 12.566...
# 1         0.182143  POLYGON ((-70.02615 12.53038, -70.02681 12.527...
# 2         0.311679  MULTIPOLYGON (((-70.00055 12.48459, -70.00096 ...
# 3         0.257761  POLYGON ((-69.95594 12.53782, -69.95615 12.537...
# 4         0.478990  MULTIPOLYGON (((-69.90684 12.49827, -69.90703 ...
# ...            ...                                                ...
# 138384    0.006466  POLYGON ((19.92334 50.04802, 19.92361 50.04760...
# 138385    0.009608  POLYGON ((19.92176 50.04978, 19.92202 50.04947...
# 138386    0.029356  POLYGON ((19.92154 50.05045, 19.92212 50.05027...
# 138387    0.010490  MULTIPOLYGON (((19.91193 50.04645, 19.91156 50...
# 138388    0.027212  POLYGON ((19.93573 50.04778, 19.93598 50.04753...
#
# [138389 rows x 12 columns]

# %%
# list of countries in LAC
my_list = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela', 'Mexico', 'Cuba', 'Dominican Republic', 'Haiti', 'Jamaica', 'Puerto Rico', 'Trinidad and Tobago', 'Bahamas', 'Barbados', 'Belize', 'Costa Rica', 'El Salvador', 'Guatemala', 'Honduras', 'Nicaragua', 'Panama', 'Antigua and Barbuda', 'Dominica', 'Grenada', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines']
# countries in the gdf in LAC
my_countries = shapefile.loc[shapefile['COUNTRY'].isin(my_list)]
# update the my_list variable for countries in LAC & available in the gdf
my_list = my_countries['COUNTRY'].unique().tolist()

# %%
import tkinter 
from tkinter import filedialog
dir_path = None
def get_file_directory():
    global dir_path
    root = tkinter.Tk()
    dir_path = filedialog.askdirectory()
    root.withdraw()       
get_file_directory()
print(dir_path)
# Out:
# J:/cms/External/TeamMembers/Adam Warren/Cresta Zones/South American Cresta Zones Per Country High Res

# %%
import os

# %%
for each_country in my_list:
    country_gdf = shapefile.loc[shapefile['COUNTRY'] == each_country]
    destination_folder = dir_path + rf'/{each_country}'
    destination_file = destination_folder + rf'/{each_country}.shp'
    os.makedirs(destination_folder)
    country_gdf.to_file(destination_file)
